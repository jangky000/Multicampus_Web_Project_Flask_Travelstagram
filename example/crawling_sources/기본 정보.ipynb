# %%
from bs4 import BeautifulSoup
import urllib.request as REQ
import urllib
import pandas as pd
import numpy as np

# %%
url_base ='https://search.naver.com/search.naver?sm=top_hty&fbm=1&ie=utf8&query='
country='프랑스'
keyword = urllib.parse.quote('%s' %country)
response = REQ.urlopen(url_base + keyword)
soup = BeautifulSoup(response, 'html.parser')
soup
# Out:
# <!DOCTYPE doctype html>
# ...

# %%
ul = soup.select_one('.nacon_area')
ul
# Out:
# <div class="nacon_area _info_area"> <div class="naflag_box"> <div class="img_naflag"> <a href="http://terms.naver.com/entry.nhn?cid=768&amp;docId=1048869&amp;categoryId=1853" nocr="" onclick="return goOtherCR(this, 'a=nco_x08*1.sum&amp;r=1&amp;i=0000000e_0000000740F4&amp;u=' + urlencode(this.href));" target="_blank"><img alt="flag" height="81" src="https://search.pstatic.net/common?type=o&amp;size=108x81&amp;quality=75&amp;direct=true&amp;src=http%3A%2F%2Fdbscthumb.phinf.naver.net%2F1230_000_1%2F20120625174547032_DP1WHVLNG.png%2F199_p.png%3Ftype%3Dm1500" width="108"/></a> </div> <div style="display: none;">국기</div> <dl class="info_naflag"> <dt><strong>프랑스</strong> France</dt> <dd><em>국가</em> 마르세유의 노래</dd> </dl> <div class="soundPlayer" id="dss_nation_player_pc"></div> <script language="javascript" type="text/javascript"> (function() { var sJavascriptFile = "https://ssl.pstatic.net/sstatic/au/outside/pc/country_info/SimpleMultiPlayer_161027.js"; var fnCallback = function() { var dss_n
# ...
