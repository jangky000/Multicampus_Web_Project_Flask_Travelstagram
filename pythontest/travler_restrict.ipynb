# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# 환경 설정
matplotlib.rcParams['font.family']='Malgun Gothic' # 제어판 글꼴 속성
matplotlib.rcParams['axes.unicode_minus'] = False # 유니코드를 적용해라

# %%
df = pd.read_excel('traveler_restrict_2015.xlsx', index_col=[0,1])
df = df.reset_index()
df.head()
# Out:
#        국가       휴대품                        통관기준
# 0  아프가니스탄         술                o 반출 및 반입 금지
# 1  아프가니스탄        담배                       o 2보루
# 2  아프가니스탄        향수                        o 1병
# 3  아프가니스탄    면세한도금액  o 여행용으로 인정되는 개인용품에 대해서는 면세
# 4  아프가니스탄  (일반면세기준)        - 단, 개인용 여부는 세관에서 판단

# %%
df[ df['국가']== '아프가니스탄']
# Out:
#         국가       휴대품                                   통관기준
# 0   아프가니스탄         술                           o 반출 및 반입 금지
# 1   아프가니스탄        담배                                  o 2보루
# 2   아프가니스탄        향수                                   o 1병
# 3   아프가니스탄    면세한도금액             o 여행용으로 인정되는 개인용품에 대해서는 면세
# 4   아프가니스탄  (일반면세기준)                   - 단, 개인용 여부는 세관에서 판단
# 5   아프가니스탄     외국환신고            o 반출 및 반입시 2만불(USD) 초과시 신고요
# 6   아프가니스탄       의약품                        o 필요 상비 의약품만 가능
# 7   아프가니스탄       의약품               - 상업용인 경우, 주재국 보건부 허가 필요
# 8   아프가니스탄        식품                      o 식품재료 및 음식 반입 가능
# 9   아프가니스탄        식품                           - 단, 돼지고기 금지
# 10  아프가니스탄    반입불허품목             o 반이슬람 물건(서적, 비디오테입등) 반입금지
# 11  아프가니스탄    반입불허품목                           o 마약, 총기류, 술
# 12  아프가니스탄    반입불허품목               - 총기 반입시 국방부 또는 내무부 허가필요
# 13  아프가니스탄    반입불허품목                         o 역사적 유물 반출 불가
# 14  아프가니스탄   기타 유의사항  o 아프가니스탄은 오랜 전란으로 명확한 규정이 확립되어 있지 않음.
# 15  아프가니스탄   기타 유의사항          - 상기 내용은 주재국 당국에 구두로 확인한 결과임.
